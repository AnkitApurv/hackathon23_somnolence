# %%
import pandas as pd
import numpy as np
from numpy import concatenate
import itertools
import re
from math import sqrt
import os
import warnings

import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib

import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller,grangercausalitytests

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM,Dropout, RNN
from keras_tuner import BayesianOptimization, RandomSearch, GridSearch
import keras
# Out:
# 2023-05-06 23:09:54.285093: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 2. Multivariate Time Series Forecasting with LSTMs

# %% [markdown]
# ## 2.1. DATA prep and EDA

# %%
country = 'france'

df_MRD = pd.read_excel(io = f'../../../data/processed/{country}.xlsx')

# %%
df_MRD.dtypes
# Out:
# Time                                                                                                                datetime64[ns]
# Unemployment_Rate_MEN                                                                                                      float64
# Unemployment_Rate_TOT                                                                                                      float64
# Unemployment_Rate_WOMEN                                                                                                    float64
# Electricity_Distribution_Losses                                                                                            float64
# Electricity_Final_Consumption_(Calculated)                                                                                 float64
# Natural_Gas_Trade_Balance                                                                                                  float64
# Economic_Activity|Industrial_Production|Index|Base_Year-2010=100                                                           float64
# Economic_Activity|Industrial_Production|Manufacturing|Index|Base_Year-2010=100                                             float64
# Industrial_Production|Seasonally_adjusted|Index|Base_Year-2010=100                                                         float64
# Financial_Market_Prices|Equities|Index|Base_Year-None                                                                      float64
# Prices|Consumer_Price_Index|All_items|Index|Base_Year-2010=100                                                             float64
# Prices|Producer_Price_Index|All_Commodities|Index|Base_Year-2010=100                                                       float64
# Labor_Markets|Unemployment_Rate|Percent                                                                                    float64
# Labor_Markets|Wage_Rates|Index                                                                                             float64
# Unemployment|Persons|Number_of                                                                                             float64
# Change_in_Inventories|Nominal|Undjusted|Domestic_Currency                                                                  float64
# Exports_of_Goods_and_Services|Nominal|Undjusted|Domestic_Currency                                                          float64
# Government_Consumption_Expenditure|Nominal|Undjusted|Domestic_Currency                                                     float64
# Gross_Domestic_Product|Nominal|Undjusted|Domestic_Currency                                                                 float64
# Gross_Fixed_Capital_Formation|Nominal|Undjusted|Domestic_Currency                                                          float64
# Household_Consumption_Expenditure|incl._NPISHs|Nominal|Undjusted|Domestic_Currency                                         float64
# Imports_of_Goods_and_Services|Nominal|Undjusted|Domestic_Currency                                                          float64
# Change_in_Inventories|Nominal|Seasonally_Adjusted|Domestic_Currency                                                        float64
# Exports_of_Goods_and_Services|Nominal|Seasonally_Adjusted|Domestic_Currency                                                float64
# Government_Final_Consumption_Expenditure|Nominal|Seasonally_adjusted|Domestic_Currency                                     float64
# Gross_Domestic_Product|Nominal|Seasonally_Adjusted|Domestic_Currency                                                       float64
# Gross_Fixed_Capital_Formation|Nominal|Seasonally_Adjusted|Domestic_Currency                                                float64
# Household_Consumption_Expenditure|incl._NPISHs|Nominal|Seasonally_Adjusted|Domestic_Currency                               float64
# Imports_of_Goods_and_Services|Nominal|Seasonally_Adjusted|Domestic_Currency                                                float64
# Change_in_Inventories|Real|Undjusted|Domestic_Currency|Base_Year-2010.0                                                    float64
# Exports_of_Goods_and_Services|Real|Undjusted|Domestic_Currency|Base_Year-2010.0                                            float64
# Government_Consumption_Expenditure|Real|Undjusted|Domestic_Currency|Base_Year-2010.0                                       float64
# Gross_Domestic_Product|Real|Undjusted|Domestic_Currency|Base_Year-2010.0                                                   float64
# Gross_Fixed_Capital_Formation|Real|Undjusted|Domestic_Currency|Base_Year-2010.0                                            float64
# Household_Consumption_Expenditure|incl._NPISHs|Real|Undjusted|Domestic_Currency|Base_Year-2010.0                           float64
# Imports_of_Goods_and_Services|Real|Undjusted|Domestic_Currency|Base_Year-2010.0                                            float64
# Change_in_Inventories|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0                                          float64
# Exports_of_Goods_and_Services|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0                                  float64
# Government_Final_Consumption_Expenditure|Real|Seasonally_adjusted|Domestic_Currency|Base_Year-2010.0                       float64
# Gross_Domestic_Product|Deflator|Seasonally_Adjusted|Base_Year-2010.0                                                       float64
# Gross_Domestic_Product|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0                                         float64
# Gross_Fixed_Capital_Formation|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0                                  float64
# Household_Consumption_Expenditure|incl._NPISHs|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0                 float64
# Imports_of_Goods_and_Services|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0                                  float64
# Consumer_Confidence                                                                                                        float64
# Business_Confidence                                                                                                        float64
# Deposit_Rate                                                                                                               float64
# Government_Bonds                                                                                                           float64
# Harmonized_Euro_Area_Rates|Loans|Households|Consumer_Credit_and_Other|Up_to_1_Year                                         float64
# Harmonized_Euro_Area_Rates|Loans|Households|House_Purchase|Over_5_Years                                                    float64
# Harmonized_Euro_Area_Rates|Loans|Non-Financial_Corporations|Up_to_1_Year                                                   float64
# Harmonized_Euro_Area_Rates|New_Business|Deposits|Households|Agreed_Maturity|Up_to_1_Year                                   float64
# Harmonized_Euro_Area_Rates|New_Business|Deposits|Non-financial_Corporations|Agreed_Maturity|Up_to_1_Year                    object
# Harmonized_Euro_Area_Rates|New_Business|Loans|Households|Consumption|Floating_Rate_and_up_to_1_Year                        float64
# Harmonized_Euro_Area_Rates|New_Business|Loans|Households|House_Purchase|Over_5_Years                                       float64
# Harmonized_Euro_Area_Rates|Outstanding_Amounts|Deposits|Households|Agreed_Maturity|Up_to_2_Years                           float64
# Harmonized_Euro_Area_Rates|Outstanding_Amounts|Deposits|Non-Financial_Corporations|Agreed_Maturity|Up_to_2_Years           float64
# dtype: object

# %%
df_MRD = df_MRD.drop(columns = [
    'Unemployment_Rate_MEN', 'Unemployment_Rate_WOMEN', 
    'Labor_Markets|Unemployment_Rate|Percent', 'Unemployment|Persons|Number_of'
    ], inplace = False
)

# %%
df_MRD = df_MRD.replace('-', np.NaN)
df_MRD['Harmonized_Euro_Area_Rates|New_Business|Deposits|Non-financial_Corporations|Agreed_Maturity|Up_to_1_Year'] = df_MRD['Harmonized_Euro_Area_Rates|New_Business|Deposits|Non-financial_Corporations|Agreed_Maturity|Up_to_1_Year'].astype(float)

# %%
df_MRD = df_MRD.set_index('Time')

# %% [markdown]
# ### 2.1.5. Scaling and Trend Analysis

# %%
scaler=MinMaxScaler()

df_MRD_scaled=scaler.fit_transform(df_MRD)
df_MRD_scaled=pd.DataFrame(df_MRD_scaled,columns=df_MRD.columns)

df_MRD_scaled.index=df_MRD.index

# %%
for col in df_MRD_scaled.columns:
    max_time=df_MRD_scaled[~df_MRD_scaled[col].isna()].index[-1]
    print('%s : %s'%(col,max_time))
# Out:
# Unemployment_Rate_TOT : 2023-02-01 00:00:00
# Electricity_Distribution_Losses : 2023-01-01 00:00:00
# Electricity_Final_Consumption_(Calculated) : 2023-01-01 00:00:00
# Natural_Gas_Trade_Balance : 2023-02-01 00:00:00
# Economic_Activity|Industrial_Production|Index|Base_Year-2010=100 : 2022-11-01 00:00:00
# Economic_Activity|Industrial_Production|Manufacturing|Index|Base_Year-2010=100 : 2022-11-01 00:00:00
# Industrial_Production|Seasonally_adjusted|Index|Base_Year-2010=100 : 2022-11-01 00:00:00
# Financial_Market_Prices|Equities|Index|Base_Year-None : 2017-04-01 00:00:00
# Prices|Consumer_Price_Index|All_items|Index|Base_Year-2010=100 : 2023-03-01 00:00:00
# Prices|Producer_Price_Index|All_Commodities|Index|Base_Year-2010=100 : 2022-12-01 00:00:00
# Labor_Markets|Wage_Rates|Index : 2016-07-01 00:00:00
# Change_in_Inventories|Nominal|Undjusted|Domestic_Currency : 2022-12-01 00:00:00
# Exports_of_Goods_and_Services|Nominal|Undjusted|Domestic_Currency : 2022-12-01 00:00:00
# Government_Consumption_Expenditure|Nominal|Undjusted|Domestic_Currency : 2022-12-01 00:00:00
# Gross_Domestic_Product|Nominal|Undjusted|Domestic_Currency : 2022-12-01 00:00:00
# Gross_Fixed_Capital_Formation|Nominal|Undjusted|Domestic_Currency : 2022-12-01 00:00:00
# Household_Consumption_Expenditure|incl._NPISHs|Nominal|Undjusted|Domestic_Currency : 2022-12-01 00:00:00
# Imports_of_Goods_and_Services|Nominal|Undjusted|Domestic_Currency : 2022-12-01 00:00:00
# Change_in_Inventories|Nominal|Seasonally_Adjusted|Domestic_Currency : 2022-12-01 00:00:00
# Exports_of_Goods_and_Services|Nominal|Seasonally_Adjusted|Domestic_Currency : 2022-12-01 00:00:00
# Government_Final_Consumption_Expenditure|Nominal|Seasonally_adjusted|Domestic_Currency : 2022-12-01 00:00:00
# Gross_Domestic_Product|Nominal|Seasonally_Adjusted|Domestic_Currency : 2022-12-01 00:00:00
# Gross_Fixed_Capital_Formation|Nominal|Seasonally_Adjusted|Domestic_Currency : 2022-12-01 00:00:00
# Household_Consumption_Expenditure|incl._NPISHs|Nominal|Seasonally_Adjusted|Domestic_Currency : 2022-12-01 00:00:00
# Imports_of_Goods_and_Services|Nominal|Seasonally_Adjusted|Domestic_Currency : 2022-12-01 00:00:00
# Change_in_Inventories|Real|Undjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Exports_of_Goods_and_Services|Real|Undjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Government_Consumption_Expenditure|Real|Undjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Gross_Domestic_Product|Real|Undjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Gross_Fixed_Capital_Formation|Real|Undjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Household_Consumption_Expenditure|incl._NPISHs|Real|Undjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Imports_of_Goods_and_Services|Real|Undjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Change_in_Inventories|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Exports_of_Goods_and_Services|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Government_Final_Consumption_Expenditure|Real|Seasonally_adjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Gross_Domestic_Product|Deflator|Seasonally_Adjusted|Base_Year-2010.0 : 2022-12-01 00:00:00
# Gross_Domestic_Product|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Gross_Fixed_Capital_Formation|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Household_Consumption_Expenditure|incl._NPISHs|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Imports_of_Goods_and_Services|Real|Seasonally_Adjusted|Domestic_Currency|Base_Year-2010.0 : 2022-12-01 00:00:00
# Consumer_Confidence : 2023-03-01 00:00:00
# Business_Confidence : 2023-03-01 00:00:00
# Deposit_Rate : 2017-04-01 00:00:00
# Government_Bonds : 2017-05-01 00:00:00
# Harmonized_Euro_Area_Rates|Loans|Households|Consumer_Credit_and_Other|Up_to_1_Year : 2022-10-01 00:00:00
# Harmonized_Euro_Area_Rates|Loans|Households|House_Purchase|Over_5_Years : 2022-10-01 00:00:00
# Harmonized_Euro_Area_Rates|Loans|Non-Financial_Corporations|Up_to_1_Year : 2022-10-01 00:00:00
# Harmonized_Euro_Area_Rates|New_Business|Deposits|Households|Agreed_Maturity|Up_to_1_Year : 2022-10-01 00:00:00
# Harmonized_Euro_Area_Rates|New_Business|Deposits|Non-financial_Corporations|Agreed_Maturity|Up_to_1_Year : 2022-10-01 00:00:00
# Harmonized_Euro_Area_Rates|New_Business|Loans|Households|Consumption|Floating_Rate_and_up_to_1_Year : 2022-10-01 00:00:00
# Harmonized_Euro_Area_Rates|New_Business|Loans|Households|House_Purchase|Over_5_Years : 2022-10-01 00:00:00
# Harmonized_Euro_Area_Rates|Outstanding_Amounts|Deposits|Households|Agreed_Maturity|Up_to_2_Years : 2022-10-01 00:00:00
# Harmonized_Euro_Area_Rates|Outstanding_Amounts|Deposits|Non-Financial_Corporations|Agreed_Maturity|Up_to_2_Years : 2022-10-01 00:00:00

# %%
# col_not_available=[
#     'Financial Market Prices, Equities, Index','Central Bank Policy Rate','Deposit Rate',
#     'Discount Rate','Lending Rate', 'Money Market Rate','Treasury Bill Rate'
# ]
                   
# col_not_available_high_correlation=['Labor Markets, Wage Rates, Index','Government Bonds']

# seasonally_adjusted_col=[col for col in df_MRD_scaled.columns if re.search(r'Seasonally Adjusted',col,re.I)]
                   
# df_MRD.drop(columns=col_not_available + col_not_available_high_correlation,inplace=True)

# %% [markdown]
# ## 2.2. Modelling

# %% [markdown]
# ### 2.2.1. Reframe time series to supervised learning

# %%
df_MRD
# Out:
#             Unemployment_Rate_TOT  Electricity_Distribution_Losses  \
# Time
# 1973-01-01                    NaN                              NaN
# 1973-02-01                    NaN                              NaN
# 1973-03-01                    NaN                              NaN
# 1973-04-01                    NaN                              NaN
# 1973-05-01                    NaN                              NaN
# ...                           ...                              ...
# 2022-11-01                    7.2                        3161.4041
# 2022-12-01                    7.2                        4243.5639
# 2023-01-01                    7.1                        4441.9905
# 2023-02-01                    7.0                              NaN
# 2023-03-01                    NaN                              NaN
#
#             Electricity_Final_Consumption_(Calculated)  \
# Time
# 1973-01-01                                         NaN
# 1973-02-01                                         NaN
# 1973-03-01                                         NaN
# 1973-04-01                                         NaN
# 1973-05-01                                         NaN
# ...                                                ...
# 2022-11-01                                  34185.0098
# 2022-12-01                                  42139.4513
# 2023-01-01                                  43463.2404
# 2023-02-01                                         NaN
# 2023-03-01                                         NaN
#
#             Natural_Gas_Trade_Balance  \
# Time
# 1973-01-01                        NaN
# 1973-02-01                        NaN
# 1973-03-01                        NaN
# 1973-04-01                        NaN
# 1973-05-01                        NaN
# ...                               ...
# 2022-11-01                   3969.360
# 2022-12-01                   4233.051
# 2023-01-01                   2890.383
# 2023-02-01                   1972.084
# 2023-03-01                        NaN
#
#             Economic_Activity|Industrial_Production|Index|Base_Year-2010=100  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                          101.78438
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Economic_Activity|Industrial_Production|Manufacturing|Index|Base_Year-2010=100  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                         102.284179
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Industrial_Production|Seasonally_adjusted|Index|Base_Year-2010=100  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                          98.391801
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Financial_Market_Prices|Equities|Index|Base_Year-None  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Prices|Consumer_Price_Index|All_items|Index|Base_Year-2010=100  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                         120.635591
# 2022-12-01                                         120.530011
# 2023-01-01                                         120.994563
# 2023-02-01                                         122.240405
# 2023-03-01                                         123.306762
#
#             Prices|Producer_Price_Index|All_Commodities|Index|Base_Year-2010=100  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                         145.432526
# 2022-12-01                                         147.093426
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             ...  Government_Bonds  \
# Time        ...
# 1973-01-01  ...               NaN
# 1973-02-01  ...               NaN
# 1973-03-01  ...               NaN
# 1973-04-01  ...               NaN
# 1973-05-01  ...               NaN
# ...         ...               ...
# 2022-11-01  ...               NaN
# 2022-12-01  ...               NaN
# 2023-01-01  ...               NaN
# 2023-02-01  ...               NaN
# 2023-03-01  ...               NaN
#
#             Harmonized_Euro_Area_Rates|Loans|Households|Consumer_Credit_and_Other|Up_to_1_Year  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Harmonized_Euro_Area_Rates|Loans|Households|House_Purchase|Over_5_Years  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Harmonized_Euro_Area_Rates|Loans|Non-Financial_Corporations|Up_to_1_Year  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Harmonized_Euro_Area_Rates|New_Business|Deposits|Households|Agreed_Maturity|Up_to_1_Year  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Harmonized_Euro_Area_Rates|New_Business|Deposits|Non-financial_Corporations|Agreed_Maturity|Up_to_1_Year  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Harmonized_Euro_Area_Rates|New_Business|Loans|Households|Consumption|Floating_Rate_and_up_to_1_Year  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Harmonized_Euro_Area_Rates|New_Business|Loans|Households|House_Purchase|Over_5_Years  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Harmonized_Euro_Area_Rates|Outstanding_Amounts|Deposits|Households|Agreed_Maturity|Up_to_2_Years  \
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
#             Harmonized_Euro_Area_Rates|Outstanding_Amounts|Deposits|Non-Financial_Corporations|Agreed_Maturity|Up_to_2_Years
# Time
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# ...                                                       ...
# 2022-11-01                                                NaN
# 2022-12-01                                                NaN
# 2023-01-01                                                NaN
# 2023-02-01                                                NaN
# 2023-03-01                                                NaN
#
# [603 rows x 53 columns]

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=False):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
reframed_dataset = series_to_supervised(df_MRD, 5, 1)

# %% [markdown]
# ### 2.2.2. Feature Selection

# %% [markdown]
# #### 2.2.2.1.Feature selection based on availability

# %%
# tlag_col=[col for col in reframed_dataset.columns if re.search(r't\)',col,re.I)==None]
# reframed_dataset_final=reframed_dataset[tlag_col+['var5(t)']]

tlag_col=[col for col in reframed_dataset.columns if re.search(r't-5',col,re.I)!=None]
reframed_dataset_final=reframed_dataset[tlag_col+['var5(t-1)','var5(t-2)','var5(t-3)','var5(t-4)']+['var5(t)']]

reframed_dataset_final.dropna(inplace=True)
reframed_dataset_final
# Out:
# /tmp/ipykernel_496990/564800525.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reframed_dataset_final.dropna(inplace=True)
#             var1(t-5)  var2(t-5)  var3(t-5)  var4(t-5)   var5(t-5)  \
# Time
# 2010-06-01        9.5   3714.714  51864.447   4074.907   95.908374
# 2010-07-01        9.4   3273.987  44840.098   4103.061   96.306747
# 2010-08-01        9.3   3320.337  44523.308   4647.923  110.747780
# 2010-09-01        9.3   2668.884  35470.487   3942.925   99.593327
# 2010-10-01        9.3   2559.778  34182.276   4124.666   94.613661
# ...               ...        ...        ...        ...         ...
# 2016-08-01       10.2   3746.478  44597.297   3875.082  109.751847
# 2016-09-01       10.1   3015.433  36657.733   4056.550  102.182754
# 2016-10-01       10.0   2463.150  32800.199   3895.750   96.406341
# 2016-11-01        9.9   2277.323  31086.577   3079.020  105.867707
# 2016-12-01        9.8   2448.581  31781.783   3644.726   93.219354
#
#              var6(t-5)   var7(t-5)   var8(t-5)   var9(t-5)  var10(t-5)  ...  \
# Time                                                                    ...
# 2010-06-01   97.648640   98.091826  104.733573   98.812226   98.512111  ...
# 2010-07-01   97.245549   97.591867   98.379753   99.361242   98.719723  ...
# 2010-08-01   99.462546   99.591701  104.651392   99.846909   98.927336  ...
# 2010-09-01   99.462546   99.191734  106.026857  100.100301   99.550173  ...
# 2010-10-01  100.167954  100.091659   95.034612  100.216439   99.550173  ...
# ...                ...         ...         ...         ...         ...  ...
# 2016-08-01  100.268727  100.091659  118.134149  105.601014  100.899654  ...
# 2016-09-01  101.477998  101.191567  118.608024  105.674919  100.380623  ...
# 2016-10-01  100.571045   99.691692  116.694114  106.107797  100.795848  ...
# 2016-11-01   99.865637   99.491709  114.571015  106.245051  101.211073  ...
# 2016-12-01  100.268727   99.191734  115.203916  105.843847  101.314879  ...
#
#             var49(t-5)  var50(t-5)  var51(t-5)  var52(t-5)  var53(t-5)  \
# Time
# 2010-06-01        0.69        7.21        3.71        2.97        1.76
# 2010-07-01        0.71        6.82        3.67        3.08        1.77
# 2010-08-01        0.78        6.61        3.52        2.97        1.61
# 2010-09-01        0.78        6.74        3.47        2.94        1.52
# 2010-10-01        0.56        6.62        3.42        2.88        1.59
# ...                ...         ...         ...         ...         ...
# 2016-08-01        0.17        4.87        1.87        1.49        0.60
# 2016-09-01        0.20        5.87        1.80        1.48        0.57
# 2016-10-01        0.17        5.69        1.70        1.44        0.55
# 2016-11-01        0.19        5.11        1.58        1.40        0.51
# 2016-12-01        0.17        5.73        1.50        1.35        0.49
#
#              var5(t-1)   var5(t-2)   var5(t-3)   var5(t-4)     var5(t)
# Time
# 2010-06-01   94.613661   99.593327  110.747780   96.306747  108.457133
# 2010-07-01  108.457133   94.613661   99.593327  110.747780   98.995767
# 2010-08-01   98.995767  108.457133   94.613661   99.593327   74.993775
# 2010-09-01   74.993775   98.995767  108.457133   94.613661  105.867707
# 2010-10-01  105.867707   74.993775   98.995767  108.457133  103.975434
# ...                ...         ...         ...         ...         ...
# 2016-08-01   93.219354  105.867707   96.406341  102.182754   78.678729
# 2016-09-01   78.678729   93.219354  105.867707   96.406341  103.477467
# 2016-10-01  103.477467   78.678729   93.219354  105.867707  101.784380
# 2016-11-01  101.784380  103.477467   78.678729   93.219354  105.469334
# 2016-12-01  105.469334  101.784380  103.477467   78.678729  103.278280
#
# [77 rows x 58 columns]

# %% [markdown]
# #### 2.2.2.1.Feature selection using causality test

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(df):
    result = adfuller(df.values)
    print('ADF Statistics: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))
    return result[1]

def check_stationarity(dataset):
    stationary_fields=[]
    non_stationary_fields=[]
    for col in dataset.columns:
        print('______%s_______'%col)
        p_value=adf_test(dataset[col])
        if p_value<=0.05:
            stationary_fields.append(col)
        else:
            non_stationary_fields.append(col)

    print('Number of stationary fields :%s'%len(stationary_fields))
    print('Number of non stationary fields :%s'%len(non_stationary_fields))
    
    return stationary_fields,non_stationary_fields

# %%
stationary_fields,non_stationary_fields=check_stationarity(reframed_dataset_final)
# Out:
# ______var1(t-5)_______
# ADF Statistics: -1.254098
# p-value: 0.649902
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var2(t-5)_______
# ADF Statistics: -2.145787
# p-value: 0.226506
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var3(t-5)_______
# ADF Statistics: -6.218036
# p-value: 0.000000
# Critical values:
# 	1%: -3.529
# 	5%: -2.904
# 	10%: -2.590
# ______var4(t-5)_______
# ADF Statistics: -2.084472
# p-value: 0.250804
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var5(t-5)_______
# ADF Statistics: -1.148124
# p-value: 0.695504
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var6(t-5)_______
# ADF Statistics: -2.349474
# p-value: 0.156507
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var7(t-5)_______
# ADF Statistics: -2.135456
# p-value: 0.230498
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var8(t-5)_______
# ADF Statistics: -1.533277
# p-value: 0.516990
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var9(t-5)_______
# ADF Statistics: -3.250057
# p-value: 0.017264
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var10(t-5)_______
# ADF Statistics: -1.838522
# p-value: 0.361511
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var11(t-5)_______
# ADF Statistics: -3.533638
# p-value: 0.007164
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var12(t-5)_______
# ADF Statistics: -1.811129
# p-value: 0.374951
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var13(t-5)_______
# ADF Statistics: -1.131614
# p-value: 0.702302
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var14(t-5)_______
# ADF Statistics: -2.406498
# p-value: 0.139911
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var15(t-5)_______
# ADF Statistics: -0.139233
# p-value: 0.945388
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var16(t-5)_______
# ADF Statistics: -2.571375
# p-value: 0.099059
# Critical values:
# 	1%: -3.532
# 	5%: -2.906
# 	10%: -2.590
# ______var17(t-5)_______
# ADF Statistics: 0.391842
# p-value: 0.981187
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var18(t-5)_______
# ADF Statistics: -1.045735
# p-value: 0.736220
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var19(t-5)_______
# ADF Statistics: -2.145931
# p-value: 0.226451
# Critical values:
# 	1%: -3.534
# 	5%: -2.906
# 	10%: -2.591
# ______var20(t-5)_______
# ADF Statistics: -1.991245
# p-value: 0.290425
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var21(t-5)_______
# ADF Statistics: -2.021132
# p-value: 0.277385
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var22(t-5)_______
# ADF Statistics: -2.249829
# p-value: 0.188660
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var23(t-5)_______
# ADF Statistics: -2.439291
# p-value: 0.130953
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var24(t-5)_______
# ADF Statistics: -1.277156
# p-value: 0.639558
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var25(t-5)_______
# ADF Statistics: -2.541785
# p-value: 0.105636
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var26(t-5)_______
# ADF Statistics: -1.873424
# p-value: 0.344665
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var27(t-5)_______
# ADF Statistics: -0.185848
# p-value: 0.940188
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var28(t-5)_______
# ADF Statistics: 0.250673
# p-value: 0.974965
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var29(t-5)_______
# ADF Statistics: -0.271206
# p-value: 0.929485
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var30(t-5)_______
# ADF Statistics: -1.724871
# p-value: 0.418346
# Critical values:
# 	1%: -3.532
# 	5%: -2.906
# 	10%: -2.590
# ______var31(t-5)_______
# ADF Statistics: 1.280534
# p-value: 0.996498
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var32(t-5)_______
# ADF Statistics: 0.907865
# p-value: 0.993192
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var33(t-5)_______
# ADF Statistics: -1.979071
# p-value: 0.295825
# Critical values:
# 	1%: -3.534
# 	5%: -2.906
# 	10%: -2.591
# ______var34(t-5)_______
# ADF Statistics: -1.373266
# p-value: 0.595024
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var35(t-5)_______
# ADF Statistics: -0.181574
# p-value: 0.940683
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var36(t-5)_______
# ADF Statistics: -0.810294
# p-value: 0.816079
# Critical values:
# 	1%: -3.529
# 	5%: -2.904
# 	10%: -2.590
# ______var37(t-5)_______
# ADF Statistics: -1.852960
# p-value: 0.354503
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var38(t-5)_______
# ADF Statistics: -1.802483
# p-value: 0.379230
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var39(t-5)_______
# ADF Statistics: 0.045784
# p-value: 0.962159
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var40(t-5)_______
# ADF Statistics: -0.439228
# p-value: 0.903340
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var41(t-5)_______
# ADF Statistics: -1.551499
# p-value: 0.507899
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var42(t-5)_______
# ADF Statistics: -3.053047
# p-value: 0.030229
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var43(t-5)_______
# ADF Statistics: -1.143582
# p-value: 0.697383
# Critical values:
# 	1%: -3.527
# 	5%: -2.904
# 	10%: -2.589
# ______var44(t-5)_______
# ADF Statistics: -0.289621
# p-value: 0.926962
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var45(t-5)_______
# ADF Statistics: 1.999480
# p-value: 0.998672
# Critical values:
# 	1%: -3.526
# 	5%: -2.903
# 	10%: -2.589
# ______var46(t-5)_______
# ADF Statistics: 3.618918
# p-value: 1.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var47(t-5)_______
# ADF Statistics: -0.574618
# p-value: 0.876615
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var48(t-5)_______
# ADF Statistics: -1.442542
# p-value: 0.561720
# Critical values:
# 	1%: -3.527
# 	5%: -2.904
# 	10%: -2.589
# ______var49(t-5)_______
# ADF Statistics: -0.974087
# p-value: 0.762598
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var50(t-5)_______
# ADF Statistics: -1.707817
# p-value: 0.427089
# Critical values:
# 	1%: -3.527
# 	5%: -2.904
# 	10%: -2.589
# ______var51(t-5)_______
# ADF Statistics: 1.380674
# p-value: 0.997025
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var52(t-5)_______
# ADF Statistics: 1.099059
# p-value: 0.995209
# Critical values:
# 	1%: -3.519
# 	5%: -2.900
# 	10%: -2.587
# ______var53(t-5)_______
# ADF Statistics: 0.915456
# p-value: 0.993289
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var5(t-1)_______
# ADF Statistics: -1.392958
# p-value: 0.585647
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var5(t-2)_______
# ADF Statistics: -1.379835
# p-value: 0.591904
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var5(t-3)_______
# ADF Statistics: -1.258230
# p-value: 0.648059
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var5(t-4)_______
# ADF Statistics: -1.191575
# p-value: 0.677209
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var5(t)_______
# ADF Statistics: -1.737459
# p-value: 0.411923
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# Number of stationary fields :4
# Number of non stationary fields :54

# %%
reframed_dataset_final_transformed = reframed_dataset_final.diff().dropna()
stationary_fields,non_stationary_fields=check_stationarity(reframed_dataset_final_transformed)
# Out:
# ______var1(t-5)_______
# ADF Statistics: -6.152297
# p-value: 0.000000
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var2(t-5)_______
# ADF Statistics: -3.417218
# p-value: 0.010386
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var3(t-5)_______
# ADF Statistics: -6.661209
# p-value: 0.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var4(t-5)_______
# ADF Statistics: -4.078998
# p-value: 0.001049
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var5(t-5)_______
# ADF Statistics: -8.470377
# p-value: 0.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var6(t-5)_______
# ADF Statistics: -7.136238
# p-value: 0.000000
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var7(t-5)_______
# ADF Statistics: -5.734098
# p-value: 0.000001
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var8(t-5)_______
# ADF Statistics: -7.722286
# p-value: 0.000000
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var9(t-5)_______
# ADF Statistics: -1.024912
# p-value: 0.744070
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var10(t-5)_______
# ADF Statistics: -5.632406
# p-value: 0.000001
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var11(t-5)_______
# ADF Statistics: -1.947304
# p-value: 0.310145
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var12(t-5)_______
# ADF Statistics: -2.091750
# p-value: 0.247845
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var13(t-5)_______
# ADF Statistics: -1.878659
# p-value: 0.342166
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var14(t-5)_______
# ADF Statistics: -6.062001
# p-value: 0.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var15(t-5)_______
# ADF Statistics: -3.676713
# p-value: 0.004453
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var16(t-5)_______
# ADF Statistics: -6.710492
# p-value: 0.000000
# Critical values:
# 	1%: -3.532
# 	5%: -2.906
# 	10%: -2.590
# ______var17(t-5)_______
# ADF Statistics: -3.508982
# p-value: 0.007759
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var18(t-5)_______
# ADF Statistics: -2.381226
# p-value: 0.147106
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var19(t-5)_______
# ADF Statistics: -2.219159
# p-value: 0.199366
# Critical values:
# 	1%: -3.534
# 	5%: -2.906
# 	10%: -2.591
# ______var20(t-5)_______
# ADF Statistics: -3.033383
# p-value: 0.031892
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var21(t-5)_______
# ADF Statistics: -1.789854
# p-value: 0.385510
# Critical values:
# 	1%: -3.526
# 	5%: -2.903
# 	10%: -2.589
# ______var22(t-5)_______
# ADF Statistics: -5.026594
# p-value: 0.000020
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var23(t-5)_______
# ADF Statistics: -4.129598
# p-value: 0.000865
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var24(t-5)_______
# ADF Statistics: -5.097541
# p-value: 0.000014
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var25(t-5)_______
# ADF Statistics: -2.794931
# p-value: 0.059002
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var26(t-5)_______
# ADF Statistics: -2.376896
# p-value: 0.148364
# Critical values:
# 	1%: -3.539
# 	5%: -2.909
# 	10%: -2.592
# ______var27(t-5)_______
# ADF Statistics: -2.592445
# p-value: 0.094569
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var28(t-5)_______
# ADF Statistics: -6.526120
# p-value: 0.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var29(t-5)_______
# ADF Statistics: -3.372253
# p-value: 0.011942
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var30(t-5)_______
# ADF Statistics: -7.119255
# p-value: 0.000000
# Critical values:
# 	1%: -3.532
# 	5%: -2.906
# 	10%: -2.590
# ______var31(t-5)_______
# ADF Statistics: -2.544721
# p-value: 0.104969
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var32(t-5)_______
# ADF Statistics: -1.938671
# p-value: 0.314093
# Critical values:
# 	1%: -3.537
# 	5%: -2.908
# 	10%: -2.591
# ______var33(t-5)_______
# ADF Statistics: -2.492676
# p-value: 0.117266
# Critical values:
# 	1%: -3.534
# 	5%: -2.906
# 	10%: -2.591
# ______var34(t-5)_______
# ADF Statistics: -3.852072
# p-value: 0.002417
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var35(t-5)_______
# ADF Statistics: -3.343125
# p-value: 0.013057
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var36(t-5)_______
# ADF Statistics: -2.323569
# p-value: 0.164479
# Critical values:
# 	1%: -3.529
# 	5%: -2.904
# 	10%: -2.590
# ______var37(t-5)_______
# ADF Statistics: -5.330497
# p-value: 0.000005
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var38(t-5)_______
# ADF Statistics: -4.628380
# p-value: 0.000114
# Critical values:
# 	1%: -3.521
# 	5%: -2.901
# 	10%: -2.588
# ______var39(t-5)_______
# ADF Statistics: -3.119465
# p-value: 0.025146
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var40(t-5)_______
# ADF Statistics: -2.860045
# p-value: 0.050195
# Critical values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
# ______var41(t-5)_______
# ADF Statistics: -6.072289
# p-value: 0.000000
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var42(t-5)_______
# ADF Statistics: -4.419100
# p-value: 0.000275
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var43(t-5)_______
# ADF Statistics: -2.047811
# p-value: 0.266011
# Critical values:
# 	1%: -3.527
# 	5%: -2.904
# 	10%: -2.589
# ______var44(t-5)_______
# ADF Statistics: -6.049257
# p-value: 0.000000
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var45(t-5)_______
# ADF Statistics: -3.957567
# p-value: 0.001650
# Critical values:
# 	1%: -3.527
# 	5%: -2.904
# 	10%: -2.589
# ______var46(t-5)_______
# ADF Statistics: -1.016961
# p-value: 0.747028
# Critical values:
# 	1%: -3.539
# 	5%: -2.909
# 	10%: -2.592
# ______var47(t-5)_______
# ADF Statistics: -3.796959
# p-value: 0.002939
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var48(t-5)_______
# ADF Statistics: -2.863518
# p-value: 0.049758
# Critical values:
# 	1%: -3.527
# 	5%: -2.904
# 	10%: -2.589
# ______var49(t-5)_______
# ADF Statistics: -3.472390
# p-value: 0.008725
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var50(t-5)_______
# ADF Statistics: -3.923569
# p-value: 0.001868
# Critical values:
# 	1%: -3.527
# 	5%: -2.904
# 	10%: -2.589
# ______var51(t-5)_______
# ADF Statistics: -3.542159
# p-value: 0.006968
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var52(t-5)_______
# ADF Statistics: -5.083853
# p-value: 0.000015
# Critical values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
# ______var53(t-5)_______
# ADF Statistics: -3.463179
# p-value: 0.008985
# Critical values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
# ______var5(t-1)_______
# ADF Statistics: -9.433806
# p-value: 0.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var5(t-2)_______
# ADF Statistics: -5.946518
# p-value: 0.000000
# Critical values:
# 	1%: -3.539
# 	5%: -2.909
# 	10%: -2.592
# ______var5(t-3)_______
# ADF Statistics: -9.436649
# p-value: 0.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var5(t-4)_______
# ADF Statistics: -9.057638
# p-value: 0.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# ______var5(t)_______
# ADF Statistics: -9.933145
# p-value: 0.000000
# Critical values:
# 	1%: -3.535
# 	5%: -2.907
# 	10%: -2.591
# Number of stationary fields :41
# Number of non stationary fields :17

# %%
reframed_dataset_final_transformed.drop(columns=non_stationary_fields,inplace=True)

# %%
correlated_col=[]
for col in [col for col in reframed_dataset_final_transformed.columns if col!='var1(t-5)']:
    print('_____________Granger Causality test between Unemployment Rate and %s___________________'%(col))
    granger_ = grangercausalitytests(reframed_dataset_final_transformed[['var1(t-5)', col]], 4)
    if (granger_[1][0]['ssr_chi2test'][1]<=0.05)|(granger_[2][0]['ssr_chi2test'][1]<=0.05)|(granger_[3][0]['ssr_chi2test'][1]<=0.05)|(granger_[4][0]['ssr_chi2test'][1]<=0.05):
        correlated_col.append(col)
# Out:
# _____________Granger Causality test between Unemployment Rate and var2(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3149  , p=0.2553  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=1.3697  , p=0.2419  , df=1
# likelihood ratio test: chi2=1.3573  , p=0.2440  , df=1
# parameter F test:         F=1.3149  , p=0.2553  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6287  , p=0.5363  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.3485  , p=0.5095  , df=2
# likelihood ratio test: chi2=1.3363  , p=0.5126  , df=2
# parameter F test:         F=0.6287  , p=0.5363  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5117  , p=0.6756  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=1.6980  , p=0.6374  , df=3
# likelihood ratio test: chi2=1.6786  , p=0.6417  , df=3
# parameter F test:         F=0.5117  , p=0.6756  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4216  , p=0.7925  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=1.9272  , p=0.7492  , df=4
# likelihood ratio test: chi2=1.9018  , p=0.7538  , df=4
# parameter F test:         F=0.4216  , p=0.7925  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var3(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7446  , p=0.3911  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.7756  , p=0.3785  , df=1
# likelihood ratio test: chi2=0.7716  , p=0.3797  , df=1
# parameter F test:         F=0.7446  , p=0.3911  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3466  , p=0.7083  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.7434  , p=0.6896  , df=2
# likelihood ratio test: chi2=0.7396  , p=0.6909  , df=2
# parameter F test:         F=0.3466  , p=0.7083  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1888  , p=0.9037  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.6264  , p=0.8904  , df=3
# likelihood ratio test: chi2=0.6237  , p=0.8910  , df=3
# parameter F test:         F=0.1888  , p=0.9037  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1640  , p=0.9558  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=0.7496  , p=0.9451  , df=4
# likelihood ratio test: chi2=0.7458  , p=0.9456  , df=4
# parameter F test:         F=0.1640  , p=0.9558  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var4(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2169  , p=0.6429  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.2259  , p=0.6346  , df=1
# likelihood ratio test: chi2=0.2256  , p=0.6348  , df=1
# parameter F test:         F=0.2169  , p=0.6429  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1813  , p=0.8346  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.3888  , p=0.8233  , df=2
# likelihood ratio test: chi2=0.3878  , p=0.8237  , df=2
# parameter F test:         F=0.1813  , p=0.8346  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2674  , p=0.8486  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.8874  , p=0.8285  , df=3
# likelihood ratio test: chi2=0.8820  , p=0.8298  , df=3
# parameter F test:         F=0.2674  , p=0.8486  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5210  , p=0.7206  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=2.3818  , p=0.6659  , df=4
# likelihood ratio test: chi2=2.3432  , p=0.6729  , df=4
# parameter F test:         F=0.5210  , p=0.7206  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var5(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2459  , p=0.6215  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.2561  , p=0.6128  , df=1
# likelihood ratio test: chi2=0.2557  , p=0.6131  , df=1
# parameter F test:         F=0.2459  , p=0.6215  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2332  , p=0.7926  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.5001  , p=0.7787  , df=2
# likelihood ratio test: chi2=0.4985  , p=0.7794  , df=2
# parameter F test:         F=0.2332  , p=0.7926  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9511  , p=0.4212  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.1558  , p=0.3682  , df=3
# likelihood ratio test: chi2=3.0895  , p=0.3780  , df=3
# parameter F test:         F=0.9511  , p=0.4212  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7770  , p=0.5443  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.5519  , p=0.4700  , df=4
# likelihood ratio test: chi2=3.4671  , p=0.4829  , df=4
# parameter F test:         F=0.7770  , p=0.5443  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var6(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.5321  , p=0.1159  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=2.6376  , p=0.1044  , df=1
# likelihood ratio test: chi2=2.5923  , p=0.1074  , df=1
# parameter F test:         F=2.5321  , p=0.1159  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2915  , p=0.2814  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=2.7701  , p=0.2503  , df=2
# likelihood ratio test: chi2=2.7195  , p=0.2567  , df=2
# parameter F test:         F=1.2915  , p=0.2814  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3042  , p=0.2805  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=4.3275  , p=0.2282  , df=3
# likelihood ratio test: chi2=4.2041  , p=0.2403  , df=3
# parameter F test:         F=1.3042  , p=0.2805  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2262  , p=0.3088  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=5.6054  , p=0.2306  , df=4
# likelihood ratio test: chi2=5.3979  , p=0.2489  , df=4
# parameter F test:         F=1.2262  , p=0.3088  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var7(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.1267  , p=0.1491  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=2.2153  , p=0.1366  , df=1
# likelihood ratio test: chi2=2.1833  , p=0.1395  , df=1
# parameter F test:         F=2.1267  , p=0.1491  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1920  , p=0.3098  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=2.5568  , p=0.2785  , df=2
# likelihood ratio test: chi2=2.5137  , p=0.2846  , df=2
# parameter F test:         F=1.1920  , p=0.3098  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9455  , p=0.4238  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.1374  , p=0.3709  , df=3
# likelihood ratio test: chi2=3.0718  , p=0.3807  , df=3
# parameter F test:         F=0.9455  , p=0.4238  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7360  , p=0.5709  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.3647  , p=0.4988  , df=4
# likelihood ratio test: chi2=3.2884  , p=0.5108  , df=4
# parameter F test:         F=0.7360  , p=0.5709  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var8(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2720  , p=0.2631  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=1.3250  , p=0.2497  , df=1
# likelihood ratio test: chi2=1.3135  , p=0.2518  , df=1
# parameter F test:         F=1.2720  , p=0.2631  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4573  , p=0.6349  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.9809  , p=0.6124  , df=2
# likelihood ratio test: chi2=0.9744  , p=0.6143  , df=2
# parameter F test:         F=0.4573  , p=0.6349  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7440  , p=0.5297  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=2.4687  , p=0.4810  , df=3
# likelihood ratio test: chi2=2.4278  , p=0.4885  , df=3
# parameter F test:         F=0.7440  , p=0.5297  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6844  , p=0.6054  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.1288  , p=0.5365  , df=4
# likelihood ratio test: chi2=3.0627  , p=0.5474  , df=4
# parameter F test:         F=0.6844  , p=0.6054  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var10(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5198  , p=0.4733  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.5415  , p=0.4618  , df=1
# likelihood ratio test: chi2=0.5395  , p=0.4626  , df=1
# parameter F test:         F=0.5198  , p=0.4733  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7875  , p=0.1750  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=3.8341  , p=0.1470  , df=2
# likelihood ratio test: chi2=3.7381  , p=0.1543  , df=2
# parameter F test:         F=1.7875  , p=0.1750  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.1989  , p=0.0088  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=13.9326 , p=0.0030  , df=3
# likelihood ratio test: chi2=12.7512 , p=0.0052  , df=3
# parameter F test:         F=4.1989  , p=0.0088  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.9109  , p=0.0067  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=17.8785 , p=0.0013  , df=4
# likelihood ratio test: chi2=15.9691 , p=0.0031  , df=4
# parameter F test:         F=3.9109  , p=0.0067  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var14(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0478  , p=0.8275  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0498  , p=0.8234  , df=1
# likelihood ratio test: chi2=0.0498  , p=0.8234  , df=1
# parameter F test:         F=0.0478  , p=0.8275  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4495  , p=0.6398  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.9642  , p=0.6175  , df=2
# likelihood ratio test: chi2=0.9579  , p=0.6194  , df=2
# parameter F test:         F=0.4495  , p=0.6398  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7598  , p=0.5207  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=2.5212  , p=0.4715  , df=3
# likelihood ratio test: chi2=2.4786  , p=0.4792  , df=3
# parameter F test:         F=0.7598  , p=0.5207  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7352  , p=0.5714  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.3609  , p=0.4993  , df=4
# likelihood ratio test: chi2=3.2848  , p=0.5113  , df=4
# parameter F test:         F=0.7352  , p=0.5714  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var15(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0315  , p=0.8597  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0328  , p=0.8563  , df=1
# likelihood ratio test: chi2=0.0328  , p=0.8563  , df=1
# parameter F test:         F=0.0315  , p=0.8597  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7396  , p=0.4811  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.5863  , p=0.4524  , df=2
# likelihood ratio test: chi2=1.5696  , p=0.4562  , df=2
# parameter F test:         F=0.7396  , p=0.4811  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1803  , p=0.3240  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.9165  , p=0.2706  , df=3
# likelihood ratio test: chi2=3.8150  , p=0.2821  , df=3
# parameter F test:         F=1.1803  , p=0.3240  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2377  , p=0.3041  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=5.6579  , p=0.2262  , df=4
# likelihood ratio test: chi2=5.4466  , p=0.2445  , df=4
# parameter F test:         F=1.2377  , p=0.3041  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var16(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0335  , p=0.8554  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0349  , p=0.8519  , df=1
# likelihood ratio test: chi2=0.0349  , p=0.8519  , df=1
# parameter F test:         F=0.0335  , p=0.8554  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6905  , p=0.5048  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.4810  , p=0.4769  , df=2
# likelihood ratio test: chi2=1.4664  , p=0.4804  , df=2
# parameter F test:         F=0.6905  , p=0.5048  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0359  , p=0.3826  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.4371  , p=0.3290  , df=3
# likelihood ratio test: chi2=3.3587  , p=0.3396  , df=3
# parameter F test:         F=1.0359  , p=0.3826  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0777  , p=0.3751  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=4.9267  , p=0.2949  , df=4
# likelihood ratio test: chi2=4.7655  , p=0.3122  , df=4
# parameter F test:         F=1.0777  , p=0.3751  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var17(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5225  , p=0.4721  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.5443  , p=0.4607  , df=1
# likelihood ratio test: chi2=0.5423  , p=0.4615  , df=1
# parameter F test:         F=0.5225  , p=0.4721  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3754  , p=0.6884  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.8051  , p=0.6686  , df=2
# likelihood ratio test: chi2=0.8008  , p=0.6701  , df=2
# parameter F test:         F=0.3754  , p=0.6884  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8742  , p=0.4590  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=2.9009  , p=0.4072  , df=3
# likelihood ratio test: chi2=2.8448  , p=0.4162  , df=3
# parameter F test:         F=0.8742  , p=0.4590  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7803  , p=0.5422  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.5672  , p=0.4677  , df=4
# likelihood ratio test: chi2=3.4817  , p=0.4807  , df=4
# parameter F test:         F=0.7803  , p=0.5422  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var20(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2372  , p=0.6277  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.2471  , p=0.6191  , df=1
# likelihood ratio test: chi2=0.2467  , p=0.6194  , df=1
# parameter F test:         F=0.2372  , p=0.6277  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1257  , p=0.8821  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.2696  , p=0.8739  , df=2
# likelihood ratio test: chi2=0.2691  , p=0.8741  , df=2
# parameter F test:         F=0.1257  , p=0.8821  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7424  , p=0.5306  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=2.4633  , p=0.4820  , df=3
# likelihood ratio test: chi2=2.4226  , p=0.4894  , df=3
# parameter F test:         F=0.7424  , p=0.5306  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7976  , p=0.5312  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.6461  , p=0.4560  , df=4
# likelihood ratio test: chi2=3.5568  , p=0.4693  , df=4
# parameter F test:         F=0.7976  , p=0.5312  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var22(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2985  , p=0.5865  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.3109  , p=0.5771  , df=1
# likelihood ratio test: chi2=0.3103  , p=0.5775  , df=1
# parameter F test:         F=0.2985  , p=0.5865  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1897  , p=0.8277  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.4068  , p=0.8159  , df=2
# likelihood ratio test: chi2=0.4057  , p=0.8164  , df=2
# parameter F test:         F=0.1897  , p=0.8277  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1507  , p=0.9289  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.5002  , p=0.9189  , df=3
# likelihood ratio test: chi2=0.4985  , p=0.9192  , df=3
# parameter F test:         F=0.1507  , p=0.9289  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9959  , p=0.4165  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=4.5525  , p=0.3364  , df=4
# likelihood ratio test: chi2=4.4143  , p=0.3528  , df=4
# parameter F test:         F=0.9959  , p=0.4165  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var23(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0290  , p=0.8652  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0302  , p=0.8619  , df=1
# likelihood ratio test: chi2=0.0302  , p=0.8619  , df=1
# parameter F test:         F=0.0290  , p=0.8652  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3573  , p=0.7009  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.7663  , p=0.6817  , df=2
# likelihood ratio test: chi2=0.7624  , p=0.6830  , df=2
# parameter F test:         F=0.3573  , p=0.7009  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6875  , p=0.5629  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=2.2813  , p=0.5161  , df=3
# likelihood ratio test: chi2=2.2464  , p=0.5229  , df=3
# parameter F test:         F=0.6875  , p=0.5629  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3200  , p=0.2723  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=6.0343  , p=0.1966  , df=4
# likelihood ratio test: chi2=5.7947  , p=0.2150  , df=4
# parameter F test:         F=1.3200  , p=0.2723  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var24(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0399  , p=0.1575  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=2.1249  , p=0.1449  , df=1
# likelihood ratio test: chi2=2.0954  , p=0.1477  , df=1
# parameter F test:         F=2.0399  , p=0.1575  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4719  , p=0.2366  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=3.1571  , p=0.2063  , df=2
# likelihood ratio test: chi2=3.0917  , p=0.2131  , df=2
# parameter F test:         F=1.4719  , p=0.2366  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0957  , p=0.3572  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.6358  , p=0.3036  , df=3
# likelihood ratio test: chi2=3.5482  , p=0.3146  , df=3
# parameter F test:         F=1.0957  , p=0.3572  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3146  , p=0.2743  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=6.0095  , p=0.1984  , df=4
# likelihood ratio test: chi2=5.7719  , p=0.2168  , df=4
# parameter F test:         F=1.3146  , p=0.2743  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var28(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0140  , p=0.9063  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0145  , p=0.9040  , df=1
# likelihood ratio test: chi2=0.0145  , p=0.9040  , df=1
# parameter F test:         F=0.0140  , p=0.9063  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5373  , p=0.5867  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.1525  , p=0.5620  , df=2
# likelihood ratio test: chi2=1.1436  , p=0.5645  , df=2
# parameter F test:         F=0.5373  , p=0.5867  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7894  , p=0.5041  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=2.6193  , p=0.4541  , df=3
# likelihood ratio test: chi2=2.5734  , p=0.4622  , df=3
# parameter F test:         F=0.7894  , p=0.5041  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7826  , p=0.5408  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.5775  , p=0.4662  , df=4
# likelihood ratio test: chi2=3.4914  , p=0.4792  , df=4
# parameter F test:         F=0.7826  , p=0.5408  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var29(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0469  , p=0.8292  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0488  , p=0.8251  , df=1
# likelihood ratio test: chi2=0.0488  , p=0.8252  , df=1
# parameter F test:         F=0.0469  , p=0.8292  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6871  , p=0.5065  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.4737  , p=0.4786  , df=2
# likelihood ratio test: chi2=1.4592  , p=0.4821  , df=2
# parameter F test:         F=0.6871  , p=0.5065  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1581  , p=0.3325  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.8426  , p=0.2790  , df=3
# likelihood ratio test: chi2=3.7449  , p=0.2904  , df=3
# parameter F test:         F=1.1581  , p=0.3325  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2407  , p=0.3029  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=5.6716  , p=0.2250  , df=4
# likelihood ratio test: chi2=5.4593  , p=0.2433  , df=4
# parameter F test:         F=1.2407  , p=0.3029  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var30(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0236  , p=0.8782  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0246  , p=0.8753  , df=1
# likelihood ratio test: chi2=0.0246  , p=0.8753  , df=1
# parameter F test:         F=0.0236  , p=0.8782  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7597  , p=0.4717  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.6294  , p=0.4428  , df=2
# likelihood ratio test: chi2=1.6117  , p=0.4467  , df=2
# parameter F test:         F=0.7597  , p=0.4717  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1013  , p=0.3550  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.6542  , p=0.3013  , df=3
# likelihood ratio test: chi2=3.5657  , p=0.3123  , df=3
# parameter F test:         F=1.1013  , p=0.3550  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1737  , p=0.3310  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=5.3655  , p=0.2518  , df=4
# likelihood ratio test: chi2=5.1750  , p=0.2698  , df=4
# parameter F test:         F=1.1737  , p=0.3310  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var34(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4911  , p=0.2260  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=1.5532  , p=0.2127  , df=1
# likelihood ratio test: chi2=1.5373  , p=0.2150  , df=1
# parameter F test:         F=1.4911  , p=0.2260  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0213  , p=0.3655  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=2.1907  , p=0.3344  , df=2
# likelihood ratio test: chi2=2.1589  , p=0.3398  , df=2
# parameter F test:         F=1.0213  , p=0.3655  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0802  , p=0.3636  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.5843  , p=0.3100  , df=3
# likelihood ratio test: chi2=3.4991  , p=0.3209  , df=3
# parameter F test:         F=1.0802  , p=0.3636  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2462  , p=0.3006  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=5.6971  , p=0.2229  , df=4
# likelihood ratio test: chi2=5.4829  , p=0.2412  , df=4
# parameter F test:         F=1.2462  , p=0.3006  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var35(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0061  , p=0.9380  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0063  , p=0.9365  , df=1
# likelihood ratio test: chi2=0.0063  , p=0.9365  , df=1
# parameter F test:         F=0.0061  , p=0.9380  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0302  , p=0.9703  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.0647  , p=0.9682  , df=2
# likelihood ratio test: chi2=0.0647  , p=0.9682  , df=2
# parameter F test:         F=0.0302  , p=0.9703  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2726  , p=0.8449  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.9047  , p=0.8243  , df=3
# likelihood ratio test: chi2=0.8991  , p=0.8256  , df=3
# parameter F test:         F=0.2726  , p=0.8449  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5021  , p=0.7343  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=2.2953  , p=0.6816  , df=4
# likelihood ratio test: chi2=2.2595  , p=0.6882  , df=4
# parameter F test:         F=0.5021  , p=0.7343  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var37(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4477  , p=0.5056  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.4664  , p=0.4947  , df=1
# likelihood ratio test: chi2=0.4649  , p=0.4953  , df=1
# parameter F test:         F=0.4477  , p=0.5056  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2295  , p=0.7955  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.4923  , p=0.7818  , df=2
# likelihood ratio test: chi2=0.4907  , p=0.7824  , df=2
# parameter F test:         F=0.2295  , p=0.7955  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1109  , p=0.9534  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.3680  , p=0.9468  , df=3
# likelihood ratio test: chi2=0.3670  , p=0.9470  , df=3
# parameter F test:         F=0.1109  , p=0.9534  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9868  , p=0.4213  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=4.5112  , p=0.3412  , df=4
# likelihood ratio test: chi2=4.3755  , p=0.3576  , df=4
# parameter F test:         F=0.9868  , p=0.4213  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var38(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0107  , p=0.9178  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0112  , p=0.9158  , df=1
# likelihood ratio test: chi2=0.0112  , p=0.9158  , df=1
# parameter F test:         F=0.0107  , p=0.9178  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4138  , p=0.6627  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.8876  , p=0.6416  , df=2
# likelihood ratio test: chi2=0.8823  , p=0.6433  , df=2
# parameter F test:         F=0.4138  , p=0.6627  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0572  , p=0.3734  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.5079  , p=0.3197  , df=3
# likelihood ratio test: chi2=3.4262  , p=0.3305  , df=3
# parameter F test:         F=1.0572  , p=0.3734  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7461  , p=0.1510  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=7.9822  , p=0.0922  , df=4
# likelihood ratio test: chi2=7.5700  , p=0.1087  , df=4
# parameter F test:         F=1.7461  , p=0.1510  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var39(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4008  , p=0.2405  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=1.4591  , p=0.2271  , df=1
# likelihood ratio test: chi2=1.4451  , p=0.2293  , df=1
# parameter F test:         F=1.4008  , p=0.2405  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1589  , p=0.3199  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=2.4858  , p=0.2885  , df=2
# likelihood ratio test: chi2=2.4450  , p=0.2945  , df=2
# parameter F test:         F=1.1589  , p=0.3199  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9664  , p=0.4139  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.2067  , p=0.3608  , df=3
# likelihood ratio test: chi2=3.1382  , p=0.3708  , df=3
# parameter F test:         F=0.9664  , p=0.4139  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2679  , p=0.2920  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=5.7962  , p=0.2149  , df=4
# likelihood ratio test: chi2=5.5747  , p=0.2332  , df=4
# parameter F test:         F=1.2679  , p=0.2920  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var41(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0123  , p=0.9119  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0128  , p=0.9098  , df=1
# likelihood ratio test: chi2=0.0128  , p=0.9098  , df=1
# parameter F test:         F=0.0123  , p=0.9119  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0032  , p=0.9968  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.0069  , p=0.9966  , df=2
# likelihood ratio test: chi2=0.0069  , p=0.9966  , df=2
# parameter F test:         F=0.0032  , p=0.9968  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1728  , p=0.9144  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.5734  , p=0.9025  , df=3
# likelihood ratio test: chi2=0.5711  , p=0.9030  , df=3
# parameter F test:         F=0.1728  , p=0.9144  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2464  , p=0.9108  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=1.1263  , p=0.8901  , df=4
# likelihood ratio test: chi2=1.1176  , p=0.8915  , df=4
# parameter F test:         F=0.2464  , p=0.9108  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var42(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5947  , p=0.4431  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.6195  , p=0.4312  , df=1
# likelihood ratio test: chi2=0.6170  , p=0.4322  , df=1
# parameter F test:         F=0.5947  , p=0.4431  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.1561  , p=0.1235  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=4.6247  , p=0.0990  , df=2
# likelihood ratio test: chi2=4.4860  , p=0.1061  , df=2
# parameter F test:         F=2.1561  , p=0.1235  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0871  , p=0.1103  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=6.9253  , p=0.0743  , df=3
# likelihood ratio test: chi2=6.6162  , p=0.0852  , df=3
# parameter F test:         F=2.0871  , p=0.1103  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5934  , p=0.1871  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=7.2841  , p=0.1216  , df=4
# likelihood ratio test: chi2=6.9388  , p=0.1392  , df=4
# parameter F test:         F=1.5934  , p=0.1871  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var44(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3549  , p=0.5532  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.3697  , p=0.5432  , df=1
# likelihood ratio test: chi2=0.3688  , p=0.5437  , df=1
# parameter F test:         F=0.3549  , p=0.5532  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6764  , p=0.5118  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.4508  , p=0.4841  , df=2
# likelihood ratio test: chi2=1.4368  , p=0.4875  , df=2
# parameter F test:         F=0.6764  , p=0.5118  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3820  , p=0.7663  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=1.2675  , p=0.7369  , df=3
# likelihood ratio test: chi2=1.2566  , p=0.7395  , df=3
# parameter F test:         F=0.3820  , p=0.7663  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5661  , p=0.6881  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=2.5880  , p=0.6289  , df=4
# likelihood ratio test: chi2=2.5426  , p=0.6370  , df=4
# parameter F test:         F=0.5661  , p=0.6881  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var45(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0017  , p=0.9674  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0018  , p=0.9666  , df=1
# likelihood ratio test: chi2=0.0018  , p=0.9666  , df=1
# parameter F test:         F=0.0017  , p=0.9674  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4028  , p=0.6700  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.8640  , p=0.6492  , df=2
# likelihood ratio test: chi2=0.8589  , p=0.6509  , df=2
# parameter F test:         F=0.4028  , p=0.6700  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4335  , p=0.7297  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=1.4385  , p=0.6965  , df=3
# likelihood ratio test: chi2=1.4246  , p=0.6998  , df=3
# parameter F test:         F=0.4335  , p=0.7297  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4792  , p=0.7509  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=2.1906  , p=0.7008  , df=4
# likelihood ratio test: chi2=2.1579  , p=0.7067  , df=4
# parameter F test:         F=0.4792  , p=0.7509  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var47(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.5293  , p=0.0214  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=5.7597  , p=0.0164  , df=1
# likelihood ratio test: chi2=5.5493  , p=0.0185  , df=1
# parameter F test:         F=5.5293  , p=0.0214  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.7263  , p=0.0725  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=5.8477  , p=0.0537  , df=2
# likelihood ratio test: chi2=5.6281  , p=0.0600  , df=2
# parameter F test:         F=2.7263  , p=0.0725  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.1062  , p=0.1078  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=6.9887  , p=0.0723  , df=3
# likelihood ratio test: chi2=6.6741  , p=0.0830  , df=3
# parameter F test:         F=2.1062  , p=0.1078  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5295  , p=0.2044  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=6.9921  , p=0.1363  , df=4
# likelihood ratio test: chi2=6.6731  , p=0.1542  , df=4
# parameter F test:         F=1.5295  , p=0.2044  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var48(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3247  , p=0.5706  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.3382  , p=0.5609  , df=1
# likelihood ratio test: chi2=0.3374  , p=0.5613  , df=1
# parameter F test:         F=0.3247  , p=0.5706  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1796  , p=0.8360  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.3853  , p=0.8248  , df=2
# likelihood ratio test: chi2=0.3843  , p=0.8252  , df=2
# parameter F test:         F=0.1796  , p=0.8360  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2915  , p=0.8314  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.9672  , p=0.8092  , df=3
# likelihood ratio test: chi2=0.9608  , p=0.8107  , df=3
# parameter F test:         F=0.2915  , p=0.8314  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7409  , p=0.5677  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.3868  , p=0.4953  , df=4
# likelihood ratio test: chi2=3.3095  , p=0.5074  , df=4
# parameter F test:         F=0.7409  , p=0.5677  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var49(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3531  , p=0.5542  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.3678  , p=0.5442  , df=1
# likelihood ratio test: chi2=0.3669  , p=0.5447  , df=1
# parameter F test:         F=0.3531  , p=0.5542  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1782  , p=0.8371  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.3823  , p=0.8260  , df=2
# likelihood ratio test: chi2=0.3813  , p=0.8264  , df=2
# parameter F test:         F=0.1782  , p=0.8371  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2127  , p=0.8873  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.7058  , p=0.8718  , df=3
# likelihood ratio test: chi2=0.7024  , p=0.8726  , df=3
# parameter F test:         F=0.2127  , p=0.8873  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3347  , p=0.8536  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=1.5303  , p=0.8213  , df=4
# likelihood ratio test: chi2=1.5142  , p=0.8241  , df=4
# parameter F test:         F=0.3347  , p=0.8536  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var50(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.4026  , p=0.1255  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=2.5027  , p=0.1137  , df=1
# likelihood ratio test: chi2=2.4618  , p=0.1166  , df=1
# parameter F test:         F=2.4026  , p=0.1255  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6506  , p=0.0778  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=5.6853  , p=0.0583  , df=2
# likelihood ratio test: chi2=5.4775  , p=0.0647  , df=2
# parameter F test:         F=2.6506  , p=0.0778  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8011  , p=0.1556  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=5.9763  , p=0.1128  , df=3
# likelihood ratio test: chi2=5.7442  , p=0.1247  , df=3
# parameter F test:         F=1.8011  , p=0.1556  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2047  , p=0.3177  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=5.5072  , p=0.2391  , df=4
# likelihood ratio test: chi2=5.3068  , p=0.2572  , df=4
# parameter F test:         F=1.2047  , p=0.3177  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var51(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0323  , p=0.8579  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.0336  , p=0.8545  , df=1
# likelihood ratio test: chi2=0.0336  , p=0.8545  , df=1
# parameter F test:         F=0.0323  , p=0.8579  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3391  , p=0.7136  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.7274  , p=0.6951  , df=2
# likelihood ratio test: chi2=0.7239  , p=0.6963  , df=2
# parameter F test:         F=0.3391  , p=0.7136  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6514  , p=0.5849  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=2.1613  , p=0.5396  , df=3
# likelihood ratio test: chi2=2.1299  , p=0.5459  , df=3
# parameter F test:         F=0.6514  , p=0.5849  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9310  , p=0.1162  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=8.8275  , p=0.0656  , df=4
# likelihood ratio test: chi2=8.3269  , p=0.0803  , df=4
# parameter F test:         F=1.9310  , p=0.1162  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var52(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.9515  , p=0.1667  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=2.0328  , p=0.1539  , df=1
# likelihood ratio test: chi2=2.0057  , p=0.1567  , df=1
# parameter F test:         F=1.9515  , p=0.1667  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5349  , p=0.2227  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=3.2922  , p=0.1928  , df=2
# likelihood ratio test: chi2=3.2211  , p=0.1998  , df=2
# parameter F test:         F=1.5349  , p=0.2227  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9778  , p=0.4087  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.2444  , p=0.3555  , df=3
# likelihood ratio test: chi2=3.1743  , p=0.3655  , df=3
# parameter F test:         F=0.9778  , p=0.4087  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8548  , p=0.1295  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=8.4789  , p=0.0755  , df=4
# likelihood ratio test: chi2=8.0157  , p=0.0910  , df=4
# parameter F test:         F=1.8548  , p=0.1295  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var53(t-5)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3380  , p=0.5628  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.3521  , p=0.5530  , df=1
# likelihood ratio test: chi2=0.3512  , p=0.5534  , df=1
# parameter F test:         F=0.3380  , p=0.5628  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3377  , p=0.7146  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.7243  , p=0.6962  , df=2
# likelihood ratio test: chi2=0.7208  , p=0.6974  , df=2
# parameter F test:         F=0.3377  , p=0.7146  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2011  , p=0.8953  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=0.6673  , p=0.8809  , df=3
# likelihood ratio test: chi2=0.6643  , p=0.8816  , df=3
# parameter F test:         F=0.2011  , p=0.8953  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4206  , p=0.2375  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=6.4941  , p=0.1652  , df=4
# likelihood ratio test: chi2=6.2178  , p=0.1835  , df=4
# parameter F test:         F=1.4206  , p=0.2375  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var5(t-1)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8309  , p=0.3651  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.8655  , p=0.3522  , df=1
# likelihood ratio test: chi2=0.8605  , p=0.3536  , df=1
# parameter F test:         F=0.8309  , p=0.3651  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6058  , p=0.5485  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.2995  , p=0.5222  , df=2
# likelihood ratio test: chi2=1.2882  , p=0.5251  , df=2
# parameter F test:         F=0.6058  , p=0.5485  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3056  , p=0.8212  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=1.0141  , p=0.7978  , df=3
# likelihood ratio test: chi2=1.0071  , p=0.7995  , df=3
# parameter F test:         F=0.3056  , p=0.8212  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8307  , p=0.5107  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=3.7975  , p=0.4341  , df=4
# likelihood ratio test: chi2=3.7007  , p=0.4480  , df=4
# parameter F test:         F=0.8307  , p=0.5107  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var5(t-2)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1151  , p=0.7354  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.1199  , p=0.7292  , df=1
# likelihood ratio test: chi2=0.1198  , p=0.7293  , df=1
# parameter F test:         F=0.1151  , p=0.7354  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2885  , p=0.7503  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.6188  , p=0.7339  , df=2
# likelihood ratio test: chi2=0.6162  , p=0.7348  , df=2
# parameter F test:         F=0.2885  , p=0.7503  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0128  , p=0.3927  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.3606  , p=0.3393  , df=3
# likelihood ratio test: chi2=3.2856  , p=0.3497  , df=3
# parameter F test:         F=1.0128  , p=0.3927  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0604  , p=0.3836  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=4.8475  , p=0.3033  , df=4
# likelihood ratio test: chi2=4.6913  , p=0.3205  , df=4
# parameter F test:         F=1.0604  , p=0.3836  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var5(t-3)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7328  , p=0.3948  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.7633  , p=0.3823  , df=1
# likelihood ratio test: chi2=0.7595  , p=0.3835  , df=1
# parameter F test:         F=0.7328  , p=0.3948  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2606  , p=0.2899  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=2.7038  , p=0.2587  , df=2
# likelihood ratio test: chi2=2.6556  , p=0.2651  , df=2
# parameter F test:         F=1.2606  , p=0.2899  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0685  , p=0.3685  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.5456  , p=0.3149  , df=3
# likelihood ratio test: chi2=3.4622  , p=0.3257  , df=3
# parameter F test:         F=1.0685  , p=0.3685  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5162  , p=0.2082  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=6.9314  , p=0.1396  , df=4
# likelihood ratio test: chi2=6.6177  , p=0.1575  , df=4
# parameter F test:         F=1.5162  , p=0.2082  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var5(t-4)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7183  , p=0.3995  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.7482  , p=0.3870  , df=1
# likelihood ratio test: chi2=0.7445  , p=0.3882  , df=1
# parameter F test:         F=0.7183  , p=0.3995  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4868  , p=0.6167  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=1.0442  , p=0.5933  , df=2
# likelihood ratio test: chi2=1.0369  , p=0.5954  , df=2
# parameter F test:         F=0.4868  , p=0.6167  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0310  , p=0.3847  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=3.4210  , p=0.3312  , df=3
# likelihood ratio test: chi2=3.3433  , p=0.3417  , df=3
# parameter F test:         F=1.0310  , p=0.3847  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1323  , p=0.3495  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=5.1760  , p=0.2697  , df=4
# likelihood ratio test: chi2=4.9985  , p=0.2875  , df=4
# parameter F test:         F=1.1323  , p=0.3495  , df_denom=63, df_num=4
# _____________Granger Causality test between Unemployment Rate and var5(t)___________________
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3054  , p=0.5822  , df_denom=72, df_num=1
# ssr based chi2 test:   chi2=0.3182  , p=0.5727  , df=1
# likelihood ratio test: chi2=0.3175  , p=0.5731  , df=1
# parameter F test:         F=0.3054  , p=0.5822  , df_denom=72, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3234  , p=0.7248  , df_denom=69, df_num=2
# ssr based chi2 test:   chi2=0.6937  , p=0.7069  , df=2
# likelihood ratio test: chi2=0.6905  , p=0.7080  , df=2
# parameter F test:         F=0.3234  , p=0.7248  , df_denom=69, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3090  , p=0.8188  , df_denom=66, df_num=3
# ssr based chi2 test:   chi2=1.0252  , p=0.7951  , df=3
# likelihood ratio test: chi2=1.0181  , p=0.7969  , df=3
# parameter F test:         F=0.3090  , p=0.8188  , df_denom=66, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2886  , p=0.8844  , df_denom=63, df_num=4
# ssr based chi2 test:   chi2=1.3191  , p=0.8581  , df=4
# likelihood ratio test: chi2=1.3072  , p=0.8602  , df=4
# parameter F test:         F=0.2886  , p=0.8844  , df_denom=63, df_num=4

# %%
reframed_dataset_final_features=reframed_dataset_final[correlated_col+['var1(t-5)']].copy()

# %%
reframed_dataset_final_features
# Out:
#             var10(t-5)  var47(t-5)  var1(t-5)
# Time
# 2010-06-01   98.512111        2.71        9.5
# 2010-07-01   98.719723        2.77        9.4
# 2010-08-01   98.927336        2.66        9.3
# 2010-09-01   99.550173        2.60        9.3
# 2010-10-01   99.550173        2.63        9.3
# ...                ...         ...        ...
# 2016-08-01  100.899654        1.78       10.2
# 2016-09-01  100.380623        1.72       10.1
# 2016-10-01  100.795848        1.67       10.0
# 2016-11-01  101.211073        1.69        9.9
# 2016-12-01  101.314879        1.66        9.8
#
# [77 rows x 3 columns]

# %% [markdown]
# ### 2.2.3. Split to train-test and reframe

# %%
scaler=MinMaxScaler()
reframed_dataset_final_scaled=scaler.fit_transform(reframed_dataset_final_features)
reframed_dataset_final_scaled=pd.DataFrame(reframed_dataset_final_scaled,columns=reframed_dataset_final_features.columns)

reframed_dataset_final_scaled.index=reframed_dataset_final_features.index

# %%
reframed_dataset_final_scaled
# Out:
#             var10(t-5)  var47(t-5)  var1(t-5)
# Time
# 2010-06-01    0.000000    0.789474   0.285714
# 2010-07-01    0.021277    0.834586   0.214286
# 2010-08-01    0.042553    0.751880   0.142857
# 2010-09-01    0.106383    0.706767   0.142857
# 2010-10-01    0.106383    0.729323   0.142857
# ...                ...         ...        ...
# 2016-08-01    0.244681    0.090226   0.785714
# 2016-09-01    0.191489    0.045113   0.714286
# 2016-10-01    0.234043    0.007519   0.642857
# 2016-11-01    0.276596    0.022556   0.571429
# 2016-12-01    0.287234    0.000000   0.500000
#
# [77 rows x 3 columns]

# %%
reframed_dataset_final_scaled_values=reframed_dataset_final_scaled.values

train_limit=reframed_dataset_final_scaled_values.shape[0]-12

train_X=reframed_dataset_final_scaled_values[0:train_limit,:-1]
train_Y=reframed_dataset_final_scaled_values[0:train_limit,-1]

test_X=reframed_dataset_final_scaled_values[train_limit:,:-1]
test_Y=reframed_dataset_final_scaled_values[train_limit:,-1]

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_Y.shape, test_X.shape, test_Y.shape)
# Out:
# (65, 1, 2) (65,) (12, 1, 2) (12,)

# %% [markdown]
# ### 2.2.4. Hyperparameter Tuning using GridSearch

# %%
# Fitting model without any hyperparameter tuning
model_no_tuned = Sequential()
model_no_tuned.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model_no_tuned.add(Dense(1))
model_no_tuned.compile(loss='mae', optimizer='adam')
# fit network
history = model_no_tuned.fit(train_X, train_Y, epochs=100, batch_size=72, validation_data=(test_X, test_Y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# 2023-05-06 23:10:19.187497: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/100
# 2023-05-06 23:10:19.595036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:10:19.597372: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:10:19.598904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-06 23:10:20.126398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:10:20.129412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:10:20.131434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-06 23:10:21.108939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:10:21.111357: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:10:21.113413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-06 23:10:23.243315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:10:23.245617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:10:23.247461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 - 4s - loss: 0.5520 - val_loss: 0.7846 - 4s/epoch - 4s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.5448 - val_loss: 0.7798 - 65ms/epoch - 65ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.5376 - val_loss: 0.7751 - 186ms/epoch - 186ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.5305 - val_loss: 0.7703 - 170ms/epoch - 170ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.5234 - val_loss: 0.7656 - 148ms/epoch - 148ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.5166 - val_loss: 0.7608 - 134ms/epoch - 134ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.5106 - val_loss: 0.7562 - 103ms/epoch - 103ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.5046 - val_loss: 0.7515 - 115ms/epoch - 115ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.4987 - val_loss: 0.7469 - 138ms/epoch - 138ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.4927 - val_loss: 0.7422 - 139ms/epoch - 139ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.4868 - val_loss: 0.7376 - 135ms/epoch - 135ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.4809 - val_loss: 0.7330 - 176ms/epoch - 176ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.4751 - val_loss: 0.7283 - 245ms/epoch - 245ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.4692 - val_loss: 0.7237 - 78ms/epoch - 78ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.4642 - val_loss: 0.7192 - 166ms/epoch - 166ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.4608 - val_loss: 0.7147 - 119ms/epoch - 119ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.4575 - val_loss: 0.7104 - 81ms/epoch - 81ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.4544 - val_loss: 0.7062 - 125ms/epoch - 125ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.4512 - val_loss: 0.7020 - 155ms/epoch - 155ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.4481 - val_loss: 0.6978 - 181ms/epoch - 181ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.4451 - val_loss: 0.6937 - 190ms/epoch - 190ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.4421 - val_loss: 0.6897 - 95ms/epoch - 95ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.4391 - val_loss: 0.6857 - 96ms/epoch - 96ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.4361 - val_loss: 0.6817 - 102ms/epoch - 102ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.4333 - val_loss: 0.6777 - 112ms/epoch - 112ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.4306 - val_loss: 0.6737 - 108ms/epoch - 108ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.4278 - val_loss: 0.6698 - 148ms/epoch - 148ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.4251 - val_loss: 0.6659 - 123ms/epoch - 123ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.4224 - val_loss: 0.6620 - 127ms/epoch - 127ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.4198 - val_loss: 0.6581 - 136ms/epoch - 136ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.4174 - val_loss: 0.6543 - 108ms/epoch - 108ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.4151 - val_loss: 0.6505 - 91ms/epoch - 91ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.4128 - val_loss: 0.6467 - 122ms/epoch - 122ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.4105 - val_loss: 0.6430 - 136ms/epoch - 136ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.4082 - val_loss: 0.6392 - 109ms/epoch - 109ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.4059 - val_loss: 0.6355 - 132ms/epoch - 132ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.4038 - val_loss: 0.6319 - 123ms/epoch - 123ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.4017 - val_loss: 0.6282 - 126ms/epoch - 126ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.3998 - val_loss: 0.6247 - 154ms/epoch - 154ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.3978 - val_loss: 0.6211 - 110ms/epoch - 110ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.3959 - val_loss: 0.6176 - 139ms/epoch - 139ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.3939 - val_loss: 0.6140 - 136ms/epoch - 136ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.3920 - val_loss: 0.6105 - 152ms/epoch - 152ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.3900 - val_loss: 0.6070 - 124ms/epoch - 124ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.3881 - val_loss: 0.6035 - 145ms/epoch - 145ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.3861 - val_loss: 0.6000 - 184ms/epoch - 184ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.3841 - val_loss: 0.5965 - 140ms/epoch - 140ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.3821 - val_loss: 0.5930 - 165ms/epoch - 165ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.3801 - val_loss: 0.5895 - 160ms/epoch - 160ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.3783 - val_loss: 0.5860 - 150ms/epoch - 150ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.3766 - val_loss: 0.5826 - 156ms/epoch - 156ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.3750 - val_loss: 0.5792 - 122ms/epoch - 122ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.3735 - val_loss: 0.5759 - 194ms/epoch - 194ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.3719 - val_loss: 0.5726 - 114ms/epoch - 114ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.3703 - val_loss: 0.5694 - 128ms/epoch - 128ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.3687 - val_loss: 0.5662 - 114ms/epoch - 114ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.3671 - val_loss: 0.5631 - 140ms/epoch - 140ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.3656 - val_loss: 0.5600 - 119ms/epoch - 119ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.3640 - val_loss: 0.5569 - 124ms/epoch - 124ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.3624 - val_loss: 0.5539 - 72ms/epoch - 72ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.3607 - val_loss: 0.5509 - 127ms/epoch - 127ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.3591 - val_loss: 0.5479 - 155ms/epoch - 155ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.3575 - val_loss: 0.5449 - 117ms/epoch - 117ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.3558 - val_loss: 0.5419 - 160ms/epoch - 160ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.3541 - val_loss: 0.5389 - 85ms/epoch - 85ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.3524 - val_loss: 0.5359 - 133ms/epoch - 133ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.3507 - val_loss: 0.5329 - 122ms/epoch - 122ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.3490 - val_loss: 0.5298 - 140ms/epoch - 140ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.3472 - val_loss: 0.5268 - 145ms/epoch - 145ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.3454 - val_loss: 0.5237 - 145ms/epoch - 145ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.3437 - val_loss: 0.5207 - 148ms/epoch - 148ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.3420 - val_loss: 0.5177 - 127ms/epoch - 127ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.3403 - val_loss: 0.5146 - 190ms/epoch - 190ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.3386 - val_loss: 0.5116 - 73ms/epoch - 73ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.3368 - val_loss: 0.5086 - 86ms/epoch - 86ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.3351 - val_loss: 0.5056 - 197ms/epoch - 197ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.3333 - val_loss: 0.5026 - 192ms/epoch - 192ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.3315 - val_loss: 0.4995 - 208ms/epoch - 208ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.3297 - val_loss: 0.4965 - 213ms/epoch - 213ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.3278 - val_loss: 0.4934 - 148ms/epoch - 148ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.3260 - val_loss: 0.4903 - 161ms/epoch - 161ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.3241 - val_loss: 0.4871 - 115ms/epoch - 115ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.3222 - val_loss: 0.4840 - 229ms/epoch - 229ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.3203 - val_loss: 0.4808 - 193ms/epoch - 193ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.3184 - val_loss: 0.4775 - 132ms/epoch - 132ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.3164 - val_loss: 0.4743 - 150ms/epoch - 150ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.3144 - val_loss: 0.4710 - 127ms/epoch - 127ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.3124 - val_loss: 0.4676 - 206ms/epoch - 206ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.3105 - val_loss: 0.4643 - 207ms/epoch - 207ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.3085 - val_loss: 0.4610 - 166ms/epoch - 166ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.3066 - val_loss: 0.4576 - 131ms/epoch - 131ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.3047 - val_loss: 0.4543 - 135ms/epoch - 135ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.3027 - val_loss: 0.4509 - 160ms/epoch - 160ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.3008 - val_loss: 0.4475 - 132ms/epoch - 132ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.2988 - val_loss: 0.4440 - 119ms/epoch - 119ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.2968 - val_loss: 0.4405 - 83ms/epoch - 83ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.2949 - val_loss: 0.4370 - 150ms/epoch - 150ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.2931 - val_loss: 0.4336 - 169ms/epoch - 169ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.2913 - val_loss: 0.4302 - 196ms/epoch - 196ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.2894 - val_loss: 0.4268 - 177ms/epoch - 177ms/step

# %%
# make a prediction
yhat = model_no_tuned.predict(test_X)

# invert scaling for forecast
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))
inv_yhat = concatenate((test_X_reshaped, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_Y_reshaped = test_Y.reshape((len(test_Y), 1))
inv_y = concatenate((test_X_reshaped,test_Y_reshaped), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
# Out:
# 1/1 [==============================] - 1s 552ms/step
# 2023-05-06 23:10:43.322350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:10:43.324195: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:10:43.326013: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %s' % rmse)
# Out:
# Test RMSE: 0.620872822001394

# %%
# Fitting best model using hyperparameter tuning
def build_model(hp):
    model = Sequential()
    
    model.add(LSTM(hp.Int('input_unit',min_value=10,max_value=500,step=1),return_sequences=True, 
                   input_shape=(train_X.shape[1],train_X.shape[2])))
    for i in range(hp.Int('n_layers', 1, 4)):
        model.add(LSTM(hp.Int(f'lstm_{i}_units',min_value=10,max_value=500,step=1),return_sequences=True))
    model.add(LSTM(hp.Int('layer_2_neurons',min_value=10,max_value=500,step=1)))
    
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.99,step=0.1)))
    
    model.add(Dense(1, activation=hp.Choice('dense_activation',values=['sigmoid','relu','tanh','linear','selu','elu'],
                                            default='relu')))
    
    model.compile(loss='mean_squared_error', 
                  optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),metrics =['mse'])
    return model

tuner= GridSearch(
        build_model,
        objective='mse',
        max_trials=10,
        executions_per_trial=1,
        overwrite=True,
        project_name=f'keras_tuning_{country}_LSTM'
        )

tuner.search(
        x=train_X,
        y=train_Y,
        epochs=100,
        batch_size=72,
        validation_data=(test_X,test_Y),
)
# Out:
# Trial 10 Complete [00h 00m 16s]
# mse: 0.008667459711432457
#
# Best mse So Far: 0.008085221983492374
# Total elapsed time: 00h 06m 10s
# INFO:tensorflow:Oracle triggered exit

# %%
best_model = tuner.get_best_models(num_models=1)[0]
# Out:
# 2023-05-06 23:16:56.717132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:16:56.719053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:16:56.720517: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-06 23:16:56.982622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:16:56.984527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:16:56.986141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-06 23:16:57.244213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:16:57.246105: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:16:57.247614: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# make a prediction
yhat = best_model.predict(test_X)

# invert scaling for forecast
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))
inv_yhat = concatenate((test_X_reshaped, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_Y_reshaped = test_Y.reshape((len(test_Y), 1))
inv_y = concatenate((test_X_reshaped,test_Y_reshaped), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
# Out:
# 2023-05-06 23:16:59.562249: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:16:59.564332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:16:59.566079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-06 23:16:59.867503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:16:59.869571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:16:59.871409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-06 23:17:00.175492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-06 23:17:00.177765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-06 23:17:00.179763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 1s 1s/step

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %s' % rmse)
# Out:
# Test RMSE: 0.22929018754133035
